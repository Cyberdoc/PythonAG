# %% [markdown]
# ### 13:45 Aufbau
#
# ### 13:55 Wiederholung
#
# Fragen:
# * Wie startet man die Python Shell?
# * Was bedeutet REPL?
# * Welche Zahlentypen / -arten kennen wir?
# * Was ist das Ergebnis der Aufgabe: 5,3 + 4,2
# * Was gilt es bei Gleitpunktzahlen zu beachten?
# * Welche 4 Grundrechenarten kennt Python, und durch welche Symbole werden sie dargestellt?
# * Kennt ihr die speziellen Rechenarten?
# ** Ganzzahl Division -> //
# ** Modulo -> %
# ** Potenz -> **
# * Welche Funktionen haben wir kennengelernt? -> abs(), round(), min(), max()
# * Welche Unterschiede gibt es bei Funktionen? -> ein Parameter, ein oder zwei Parameter, beliebig viele Parameter
#
# ### 14:10 Variablen
#
# Um einen Wert zu speichern, kann man ihn in einer Variablen speichern
# ```x = 1```
#
# Inhalt der Variable ausgeben ```print(x)```
#
# Anders als in Mathe steht das "Ergebnis" vorne:
# Mathe ```Summand_1 + Summand_2 = Summe```
# Informatik ```Summe = Summand_1 + Summand_2```
#
# ### 14:20 Regeln Variablen Namen
#
# Die Regeln: Ein Variablenname...
#
# * besteht aus Buchstaben (a...z,A...Z), Ziffern (0..9) oder Unterstrichen (_)
# * beginnt mit einem Buchstaben oder einem Unterstrich
# * darf kein reserviertes Wort sein (z.B. not, if, etc.)
# * sollte keinem Funktionsnamen entsprechen (z.B. abs, int, etc.)
#
# Beispiele für gültige Namen:
# * richtig
# * _richtig
# * Richtig1
# * richtigerName
# * dieser_Name_ist_auch_erlaubt
#
# Beispiele für ungültige Namen:
# * 2_Werte
# * dieser-ist-ein-ungültiger
#
# ### 14:25 Besonderheiten
#
# x++ -> x = x + 1
# x+=5 -> x = x + 5
# runden = round() -> Danach kann man die Funktion round() auch mit runden() aufrufen (sollte man aber nicht machen)
#
# ## Alternative 1
# ### 14:30
# Ein paar Rechenaufgaben mit Variablen:
# * Umfang - Rechteck und Kreis
# * Fläche
#
#
# ## Alternative 2
# ### 14:30 import
#
# 1. Vairante
# ```import math```
# Hier wird die Bibliothek __math__, welche uns weitere mathematische Funktionen zur Verfügung stellt, geladen. Wenn man diese Funktionen verwenden will, muss man dem Funktionsnamen, immer das Wort __math__ voranstellen:
# ```math.pi```
# Zum Zugriff auf die Zahl __pi__ (Pi ist eine Konstante, dies ist einer Variable, mit einem Festzugewiesenen Wert, der nicht geändert werden kann)
#
# 2. Variante
# ```import math as m```
# Hiermit bekommt die Bibliothek einen Alias oder Alternativnamen, nämlich in diesem Fall, den Buchstaben __m___. Damit sieht der Zugrffi auf __pi__ so aus:
# ```m.pi```
#
# 3. Variante
# ```from math import pi```
# Dadurch wird nur __pi__ von der __math__ Bibliothek eingebunden, und kann direkt verwendet werden ohne vorangestellten Bibliotheksnamen, was dass so aussieht:
# ```pi```
#
# 4. Variante
# ```from math import *```
# So werden alle Funktionen und Konstanten von __math__ eingebunden. Dadurch kann es wieder zu Nebenwirkungen kommen, wenn man eine Funktion mit gleichen Namen verwendet, wie in der Library __math__. Die Schreibweise ist identisch zur 3. Variante.
#
# ### 14:50 Abbau
#
# ---
#
# Wenn die Zeit reicht, dann help Funktion und math gcd als Beispiel finden lassen
