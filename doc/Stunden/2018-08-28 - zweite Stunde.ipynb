# %% [markdown]
# ### 13:45
#
# Aufbau der RasPis
#
# ### 13:55
#
# Kurze Demo, wie man die IDLE startet, mit anschließendem "Hello World"
#
# ```>>> print('Hello World')```
#
# Jeder startet die IDLE und lässt das "Hello World" laufen
#
# ### 14:05
#
# Zahlen - Grundrechenarten + - * /
#
# **Beispiel Taschenrechner**
#
# ```>>> 5 + 5```
#
# Danach Beispiel für fehlerhafte Syntax
#
# ```>>> 5 + ```
#
# ### 14:10
#
# Die Gruppe soll mit den einfache Rechnungen herumspielen
# An die Tafel ein paar einfache Rechnungen schreiben, für jede Gruppe eine
#
# * G1: 558 / 124 = 4.5
# * G2: 13 * 18 = 234
# * G3: 4516 - 2312 = 2204
# * G4: 329 + 1213 = 1542
# * G5: 1664 / 256 = 6.5
# * G6: 26 * 56 = 1456
# * G7: 3673 - 1781 = 1892
# * G8: 4261 + 3251 = 7512
#
# Klammern wie in der Mathematik, auch hier Syntax beachten
# Kurzes Beispiel ohne Übung (einmal korrekt, einmal Fehler)
#
# ### 14:25
#
# Sonder Operatoren
#
# * \*\* Potenz-Berechnung  2\*\*2 = 4
# * // Ganzzahl Division  5 // 2 = 2
# * % Modulo (Rest)       5 % 2 = 1
#
# Beispiele:
# * 8 hoch 4 = 4096
# * 131 // 12 = 10
# * 131 % 12 = 11
#
# ### 14:35
#
# Ganze Zahlen (int)
# Kommazahlen (float) -> Gleitpunktzahlen
#
# Beispiel:
#
# ```>>> 5.3 + 4.2```
#
# Falsches Bespiel:
#
# ```>>> 5,3 + 4,2```
#
# Ergebnis: (5, 7, 2) warum?
#
# ### 14:45
#
# Mathematische Funktionen:
#
# **max() / min() / abs() / round() / int() / float() / type()**
#
# Unterschiede bei den Übergabe Parametern hervorheben
#
# * max/min - Liste
# * abs - ein Wert
# * round - ein oder zwei Werte
#
# ### 15:05
#
# Abbau
#
# ### 15:15
#
# Ende der AG
