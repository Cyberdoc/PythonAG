# %% [markdown]
# ### 13:45 Aufbau + Wiederholung
# * Welche drei Datentypen kennen wir?
#   * String -- Text
#   * int    -- natürliche ganze Zahl
#   * float  -- Gleitkommazahl
# * Gebe das Wort __Beispiel__ mit der Funktion *print* aus
# * Gebe die Zahl __5__ mit der Funktion *print* aus
#
# ### 14:15 - if
#
# ```
# if <Bedingung>:
#     <Verarbeitungsblock>
# ```
#
# Bedingung kann WAHR oder FALSCH sein.
#
# Vergleiche mit ==, !=, <, >, <=, >=
#
#
# ### 14:20 - Aufgabe
#
# * Bestimme den Block unter dem Spieler
# * Handelt es sich bei dem Block um Gras, dann pflanze eine gelbe Blume auf dem Block
#
# ### 14:30 - Pause
#
# ### 14:35 - else
#
# ```
# if <Bedingung>:
#     <Verarbeitungsblock>
# else:
#     <Verarbeitungsblock>
# ```
#
# ### 14:40 - Aufgabe
#
# * Erweitere das Programm, dass es einen roten Pilz pflanzt, wenn sich kein Gras unter dem Spieler befindet
#
# ### 14:45 - elif
#
# ```
# if <Bedingung>:
#     <Verarbeitungsblock>
# elif <Bedingung>:
#     <Verarbeitungsblock>
# else:
#     <Verarbeitungsblock>
# ```
#
# ### 14:50 - Aufgabe
#
# * Erweitere das Programm: Wenn sich Erde unter dem Spieler befindet soll eine cyan Blume gepflanzt werden
#
# | ID | Typ        |
# |----|------------|
# | 0  | Luft       |
# | 1  | Stein      |
# | 2  | Gras       |
# | 3  | Erde/Dreck |
# | 12 | Sand       |
# | 37 | Blume gelb |
# | 38 | Blume cyan |
# | 39 | Pilz braun |
# | 40 | Pilz rot   |
#
#
# ### 15:00 Abbau
